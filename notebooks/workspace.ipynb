# %%
from databricks.sdk import WorkspaceClient
# Out:
# /Users/scott.mckean/Repos/databricks-sdk-demo/.venv/lib/python3.12/site-packages/databricks/sdk/service/jobs.py:60: SyntaxWarning: invalid escape sequence '\.'
#   """The sequence number of this run attempt for a triggered job run. The initial attempt of a run
# /Users/scott.mckean/Repos/databricks-sdk-demo/.venv/lib/python3.12/site-packages/databricks/sdk/service/jobs.py:2571: SyntaxWarning: invalid escape sequence '\.'
#   """The sequence number of this run attempt for a triggered job run. The initial attempt of a run
# /Users/scott.mckean/Repos/databricks-sdk-demo/.venv/lib/python3.12/site-packages/databricks/sdk/service/jobs.py:3417: SyntaxWarning: invalid escape sequence '\.'
#   """The sequence number of this run attempt for a triggered job run. The initial attempt of a run

# %%
w = WorkspaceClient()
for c in w.clusters.list():
  print(c.cluster_name)
# Out:
# Shared Americas - UC
# Shared Autoscaling Americas
# Shared Autoscaling EMEA
# Shared Compute - UC - 14.3
# Amine Nouira's Cluster
# Ben Doan's Cluster
# Brian McConnell's Personal Compute Cluster
# chris_koester
# dbdemos-llm-rag-chatbot-yash_gupta
# dlt-execution-b80f5eb2-25bd-4207-b02b-c06bbaa86f97
# dlt-execution-c73c194e-a87c-44dc-b33c-4d48722c2cff
# Duncan Davis's Cluster
# josh.melton's Cluster
# Mark Gilbert's Cluster
# msh-cpu-singlenode-1
# Nick Ceneviva's Cluster
# Phil Salm's Cluster
# Product Matching Demo Cluster
# qyu_multi-nodes
# Rahul Jagannathan's Default Termination Time - Personal Compute Cluster
# Scott McKean's DBAcademy Cluster
# sgcc-mlr
# Sindhu Murugavel's Cluster
# Thiago da Hora's Cluster
# TS Demo
# ys_demo
# dlt-execution-56d01a8d-19d7-4fc8-9249-ad3c717e2fbb
# 11.3 2 workers - 2
# 13ml_gpu
# 13ML_GPU_NC12s_v3
# 14ML PC S_DS5_V2
# 14ML_GPU_SINGLE_NODE_STD_NC8AS_T4_V3_56GB
# Adrian Tompkins's Cluster
# Alex Nastetsky's Cluster
# Andrei Kostunin's Cluster
# Carlos del Castillo's Cluster UC
# dbdemos-auto-loader-mark_gilbert
# dbdemos-delta-lake-elmer_cecilio
# dbdemos-lakehouse-iot-platform-shunichiro_takeshita
# dbdemos-lakehouse-retail-c360-kuldeep_singh
# dbdemos-llm-dolly-chatbot-oliver_koernig
# dbdemos-llm-dolly-chatbot-pete_heywood
# dbdemos-llm-rag-chatbot-elmer_cecilio
# dbdemos-llm-rag-chatbot-ivy_lu
# dbdemos-llm-rag-chatbot-miguel_peralvo
# dbdemos-llm-rag-chatbot-shunichiro_takeshita
# dbdemos-mlops-end2end-ivy_lu
# dbdemos-mlops-end2end-miguel_peralvo
# dbdemos-sql-ai-functions-miguel_peralvo
# dbdemos-uc-01-acl-elmer_cecilio
# dbdemos-uc-04-system-tables-purvang_parikh
# Diego Alfaro's Cluster
# Dipankar Kushari's Cluster - No spark config
# Dipankar Kushari's Cluster for Test SP
# Dipankar Kushari's SP Cluster
# DK Shared Pool Cluster
# EC Demo Cluster
# EC ML Single Node
# Elmer Cecilio's Cluster
# Ganesh Chand's Cluster
# Ganesh Dogiparthi's Cluster
# ggw_pc_ml
# ggw_uc
# Gireesh LLM CPU
# Gireesh ML Single-node CPU
# gm-ui-cluster-ml
# gm-ui-cluster-personal
# Grzegorz Rusin's Cluster
# Grzegorz Rusin's Cluster - ML
# Himanshu Arora's Cluster - Skew Demo
# HimCluster STDF
# JK SN 14.3 LTS ML
# JKBank-Demo-Cluster-DoNotDelete
# jralfonsog-ML
# jralfonsog-shared
# Kapil Budhraja's Cluster
# Karthik Subramanya's Cluster
# Krishna Satyavarapu Casey Init script
# Kuldeep Singh's Cluster v11.3.x
# Laurent sbx 14.3 (assigned)
# Laurent sbx 14.3 (shared)
# Laxmi-UC-Single
# Luis Herrera - Testing Cluster
# Madhav Narendran's Cluster
# mas-ml-cluster
# mas-ml-gpu-cluster
# mas-ml-gpu-single
# mas-ml-gpu-single-nkd
# mas-ml-single
# Mathieu Lidar Test
# Michele Lamarca's Personal Compute Cluster
# miguel_shared_cluster_UC
# Mladen Kovacevic's Cluster
# MLFlow-eval-cluster
# mmt_dbr14.3LTS_ML_cpu
# mmt_dbr14.3LTS_ML_libloads_r
# Mosaic Demo
# nklc non_ml
# nklc_ml
# OCI mTLS Cluster
# Orrin Edenfield (Databricks)'s Cluster
# Orrin Edenfield's Cluster
# Pete Heywood's ML GPU Cluster
# qing-uc-shared
# ry-gpu-large
# Scott Eade's DBR 13.3 LTS Cluster
# Scott Eade's DBR 13.3 LTS Photon Cluster
# sdonohoo-finetuning
# sdonohoo-ml-gpu
# Shared Autoscaling APJ
# Shrey Mehta's Personal Compute Cluster
# Shunichiro Takeshita's Cluster
# SNCF Cluster
# Srikanth Mallisetti's Cluster
# Surya Sai Turaga's Cluster
# timmannel_legacy_uc_cluster
# timmannel_nba_uc_multinode
# timmannel_nba_uc_singlenode_2
# wsilveira_ml_133
# wsilveira_ml_gpu_143
# Xavier Armitage's Cluster
# Xin Chen's Standard Cluster
# 14.3 computer-vision-corn-dennis_schultz
# Abdi Abdullahi's Cluster
# Adam Wasserman's Cluster
# AJ ML Demo Cluster
# AJ ML Demo Cluster
# Aleksandra Semenenko's Cluster
# Alex Linke's Cluster
# Alex Nastetsky's Cluster 14.3
# alex.hunt's ML Cluster
# Amine Nouira's Cluster 2024-07-30 21:52:34
# arun_t_llm_RAG
# Arun_T_Variant_Test
# Brian Rehrey's Cluster
# Brian Rehrey's Single Node Cluster
# cgrant-15
# Chang Shi Lim's Cluster
# Claudio Seidi Takamiya's Personal Compute Cluster
# ClsTestML
# Daniel Perez Garcia's ML
# daniel.perez's Cluster
# dbdemos-auto-loader-bradley_munday
# dbdemos-cdc-pipeline-oliver_koernig
# dbdemos-computer-vision-pcb-dennis_schultz
# dbdemos-delta-lake-bradley_munday
# dbdemos-delta-lake-kyle_hachey
# dbdemos-delta-sharing-airlines-srikanthkumar_rana
# dbdemos-dlt-cdc-bradley_munday
# dbdemos-dlt-cdc-oliver_koernig
# dbdemos-dlt-loans-larissa_xavierdemelo
# dbdemos-dlt-loans-oliver_koernig
# dbdemos-dlt-loans-yared_gudeta
# dbdemos-feature-store-alex_linke
# dbdemos-lakehouse-fsi-credit-irfan_elahi
# dbdemos-lakehouse-fsi-fraud-kuldeep_singh
# dbdemos-lakehouse-fsi-smart-claims-nikolay_manchev
# dbdemos-lakehouse-fsi-smart-claims-oliver_koernig
# dbdemos-lakehouse-fsi-smart-claims-romy_li
# dbdemos-lakehouse-hls-readmission-emma_yamada
# dbdemos-lakehouse-iot-platform-adrian_tompkins
# dbdemos-lakehouse-iot-platform-emma_yamada
# dbdemos-lakehouse-iot-platform-romy_li
# dbdemos-lakehouse-monitoring-emma_yamada
# dbdemos-lakehouse-monitoring-larissa_xavierdemelo
# dbdemos-lakehouse-retail-c360-irfan_maroof
# dbdemos-lakehouse-retail-c360-marco_garcia
# dbdemos-lakehouse-retail-c360-pamela_pettit
# dbdemos-llm-fine-tuning-ehsan_olfat
# dbdemos-llm-fine-tuning-paul_signorelli
# dbdemos-llm-fine-tuning-rahul_jagannathan
# dbdemos-llm-rag-chatbot-adrian_tompkins
# dbdemos-llm-rag-chatbot-amine_nouira
# dbdemos-llm-rag-chatbot-arun_thiagarajan
# dbdemos-llm-rag-chatbot-brian_mcconnell
# dbdemos-llm-rag-chatbot-ellen_hoeven
# dbdemos-llm-rag-chatbot-gopalakrishnan_anantharaman
# dbdemos-llm-rag-chatbot-nikolay_manchev
# dbdemos-llm-rag-chatbot-omar_hamdan
# dbdemos-llm-rag-chatbot-piero_ocampo
# dbdemos-llm-rag-chatbot-riley_rustad
# dbdemos-llm-rag-chatbot-ryuta_yoshimatsu
# dbdemos-llm-rag-chatbot-scott_donohoo
# dbdemos-llm-rag-chatbot-stuart_lynn
# dbdemos-llm-rag-chatbot-yuqing_su
# dbdemos-mlops-end2end-ana_sanchez
# dbdemos-mlops-end2end-ana_sanchez
# dbdemos-mlops-end2end-arun_wagle
# dbdemos-mlops-end2end-emma_yamada
# dbdemos-mlops-end2end-oliver_koernig
# dbdemos-mlops-end2end-pamela_pettit
# dbdemos-uc-03-data-lineage-bradley_munday
# dbdemos-uc-04-system-tables-arun_wagle
# dbdemos-uc-04-system-tables-ryan_wyllie
# dbdemos-uc-04-system-tables-sam_jarvis
# dbdemos-uc-04-system-tables-santosh_katrathanda
# de-jk
# dlt-meta-onboarding-cluster-0b49394083a74be4a3e06e59a81b7a85
# dlt-meta-onboarding-cluster-581b970adb28470e856383de0c4a7d16
# dlt-meta-onboarding-cluster-60b485f7bd514c6bafeb9464c26ba875
# dlt-meta-onboarding-cluster-784ff36db635437ca5b57e89c7a47aa2
# dlt-meta-onboarding-cluster-e1190c5a1d664d3bb24a22d45fe08c0c
# Duncan Davis's Cluster
# eo_ML_15.3
# eo_ML_no_GPU
# ER - Cluster
# Felix 15.3
# FNeiva Entity Resolution LLM
# Fábio Gonçalves's Cluster
# Ganesh-ML
# Gary Diana's Power User Compute Cluster
# general-cluster-mg
# gguitarts-misc-uc-tests
# Gopalakrishnan Anantharaman's Cluster
# hinak-ap-single-standard-15.3
# Howard Wong's Cluster
# ie_01_duckdb
# im_ml_in_prod_v2
# Insung Lee's Cluster 15.3 ML(CPU)
# irfan.maroof's Cluster
# Jaiminkumar Shah's Cluster
# Jenny Zhu's Cluster
# Jenny Zhu's ML Cluster
# Jesse Young's Cluster
# job-1001265932100486-run-311428040606451
# job-1095013162745351-run-115501840072840
# job-1095013162745351-run-839126643157088
# job-1103149249577667-run-763894473249997-job_cluster
# job-184424386651733-run-169744651071554-write_feature_table_job_cluster
# job-211503131967399-run-306274669308968-model_training_job_cluster
# job-30599421126675-run-928693788486011
# job-533686586505367-run-861769322244269
# job-570087408432694-run-1000343888880368-Backup_cluster
# job-570087408432694-run-274171265401655-Backup_cluster
# job-570087408432694-run-414380031312431-Backup_cluster
# job-570087408432694-run-983730473270831-Backup_cluster
# job-640127159250541-run-500483489098887-Shared_job_cluster
# job-640127159250541-run-600638004504522-Shared_job_cluster
# job-721194645742118-run-794678390080330-model_training_job_cluster
# job-736496267080992-run-1099764753042768-job_cluster
# job-749656685610214-run-1063480168799628-Backup_cluster
# job-749656685610214-run-1115264150766683-Backup_cluster
# job-749656685610214-run-166541074512801-Backup_cluster
# job-749656685610214-run-22712823274131-Backup_cluster
# job-755425242829903-run-538880155955097-Query_HL7_Messages_Stream_cluster
# job-788940121309820-run-1034219511191831-Backup_cluster
# job-788940121309820-run-18228985771053-Backup_cluster
# job-788940121309820-run-330939239764317-Backup_cluster
# job-788940121309820-run-968027447330517-Backup_cluster
# job-809233694892118-run-1063352956471021-Shared_job_cluster
# job-92099858872839-run-1049520085801995-mmf_cluster
# job-926420393139383-run-695023890348728-Shared_job_cluster_v3
# job-939266477137961-run-624725392722406-model_training_job_cluster
# job-985669288881303-run-369133913713450
# John Snow Labs
# Jonathan Cheung's Cluster
# jscalia_ml_cluster
# Karthiga Mahalingam's Cluster
# keerthi.josyula's Cluster
# Kivanc Urgancioglu's Default Termination Time - Personal Compute Cluster
# komae_14.3_lts_ml_NC48ads_A100_v4
# kotaiba cluster
# ktzsh-mlops
# Larissa Xavier de Melo's Cluster
# learning-genai
# Leon Eller's Cluster
# llm-fine-tuning-register-paul_signorelli
# Lukas Peterson's Cluster
# Luke Gordon's Ben_catboost Cluster
# Mandy Baker's Cluster
# Manfred Cluster ML
# Marcell Ferencz's GPU Cluster
# Marcell Ferencz's ML Cluster
# Marcell's Mosaic Cluster
# Marco Boniche's Cluster
# Mark Gilbert's Cluster ML
# Mark Gilbert's Cluster vscode
# Matthieu Lamairesse's Cluster
# Matthieu Lamairesse's Shared Cluster
# Mehdi Modarressi's Cluster 14.3_shared
# Mehdi's Cluster 64
# Mehdi's Cluster 8 (clone)
# Mehdi's XS Multi
# Michael Davison's Cluster
# Miriam Qunell's Cluster
# Mirnes Salkic's Cluster
# mmf_cluster
# Morgan Williams's Cluster
# Morgan Williams's GPU Cluster
# Morgan Williams's SingleNode GPU Cluster
# nate-fleming-14.3 LTS ML GPU
# nate-fleming-15.3 ML
# nikolay.manchev's Cluster
# Nitin Chaudhary's Cluster
# OS Height
# Parexel RWE Cluster
# Pete Heywood's Assigned 14.3 Cluster
# Piero Ocampo-Gonzalez's Cluster
# qian_gpu
# Rahul Jagannathan's GPU Cluster
# Ray Notebooks
# read from volumes
# Remorph PC
# riley_autoML_county
# Robert Whiffin's Cluster
# Roger Ding's Cluster
# rohit.bhagwat's Cluster
# Romy Li's Cluster
# ronans_10_4
# rs_14_3_LTS
# ry-cv-quality-inspection
# ry-gpu-14
# ry-gpu-15
# Ryuta Yoshimatsu's Cluster
# ryuta.yoshimatsu's Cluster
# Sabir Ayappalli's Personal Compute Cluster
# Sandesh D's DBAcademy Cluster
# Sanja Jovanovic's Cluster
# SATUnstructured
# Saurabh Shukla's Single Cluster
# Scott Donohoo's Cluster
# Shoki Kato's Cluster_ML_Single_Node
# Shujing Yang's Ben_catboost Cluster
# Single_User-Subhadip
# sri-whisper-a10
# sri.tikkireddy's Cluster
# sri.tikkireddy@databricks.com's Cluster
# sricci_multinode_14.3ML_LTS
# Sriharsha Jana's Single Node
# Srikanth Kumar Rana's Cluster
# Srikanth Kumar Rana's Cluster
# Sriram Vadlamani ML_11.3
# Stephanie Behrens's Cluster
# Sudharshan Rajan's Cluster
# Sunny Cluster
# Swaroop Oggu's Cluster
# Swaroop Oggu's Shared Compute Cluster
# Thomas Bayzelon's Personal Compute Cluster
# Tian Tan's Cluster
# Tim Stanton's Cluster
# TJ Cycyota's Cluster
# UDF Testing Cluster
# Variant demo
# vgd_experiments
# wittprojects
# wyia-14.3lts-ml
# xlsx_2_csv
# Yash Gupta's Compute Cluster
# Yash Gupta's JSL Cluster
# YG_ML_PRO
# yi.wang's personal compute
# Ziviles Lab

# %%
d = w.dbutils.fs.ls('/')

for f in d:
  print(f.path)
# Out:
# /984752964297111
# /FileStore
# /Shared
# /Users
# /Volume
# /Volumes
# /Workspace
# /cluster-logs
# /databricks
# /databricks-datasets
# /databricks-datasets-private
# /databricks-results
# /databricks_solacc
# /dbdemos
# /dbfs
# /demos
# /dlt-meta_cli_demo_3c11370957ea400d8db28719c84fb59d
# /home
# /johnsnowlabs
# /local_disk0
# /ml
# /mnt
# /path
# /pcb1
# /pipelines
# /pj
# /root
# /solacc
# /solution_accelerator
# /terraform
# /tmp
# /user
# /volume
# /volumes

# %%
from databricks.sdk.runtime import *

d = dbutils.fs.ls('/')

for f in d:
  print(f.path)
# Out:
# /984752964297111
# /FileStore
# /Shared
# /Users
# /Volume
# /Volumes
# /Workspace
# /cluster-logs
# /databricks
# /databricks-datasets
# /databricks-datasets-private
# /databricks-results
# /databricks_solacc
# /dbdemos
# /dbfs
# /demos
# /dlt-meta_cli_demo_3c11370957ea400d8db28719c84fb59d
# /home
# /johnsnowlabs
# /local_disk0
# /ml
# /mnt
# /path
# /pcb1
# /pipelines
# /pj
# /root
# /solacc
# /solution_accelerator
# /terraform
# /tmp
# /user
# /volume
# /volumes
